# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.show()

# %%
import numpy as np

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y)

# %%
fig,axes=plt.subplots()
axes.plot(x,y,label='x square',color='green')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.legend(loc=(10))
